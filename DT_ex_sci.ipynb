# %%
#load the data
import pandas as pd
import numpy as np
data = pd.read_csv('./iris_data.csv')
data.head()
X = data.drop(['target','label'],axis=1)
y = data.loc[:,'label']
print(X.shape,y.shape)
# Out:
# (150, 4) (150,)

# %%
from sklearn import tree
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf=5)
dc_tree.fit(X,y)
y_predict = dc_tree.predict(X)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y,y_predict)
print(accuracy)
# Out:
# 0.9733333333333334

# %%
import matplotlib as mpl
font2 = {'family' : 'SimHei',
'weight' : 'normal',
'size'   : 20,
}
mpl.rcParams['font.family'] = 'SimHei'
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20,20))
tree.plot_tree(dc_tree,filled='True',
               feature_names=['花萼长', '花萼宽', '花瓣长', '花瓣宽'],
               class_names=['山鸢尾', '变色鸢尾', '维吉尼亚鸢尾'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 14
#      10 fig = plt.figure(figsize=(20,20))
#      11 tree.plot_tree(dc_tree,filled='True',
#      12                feature_names=['花萼长', '花萼宽', '花瓣长', '花瓣宽'],
#      13                class_names=['山鸢尾', '变色鸢尾', '维吉尼亚鸢尾'])
# ---> 14 plt.savefig('D:/桌面/1.png', bbox_inches='tight', pad_inches=0.0)
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\pyplot.py:966, in savefig(*args, **kwargs)
#     963 @_copy_docstring_and_deprecators(Figure.savefig)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\figure.py:3005, in Figure.savefig(self, fname, transparent, **kwargs)
#    3002         patch.set_facecolor('none')
#    3003         patch.set_edgecolor('none')
# -> 3005 self.canvas.print_figure(fname, **kwargs)
#    3007 if transparent:
#    3008     for ax, cc in zip(self.axes, original_axes_colors):
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\backend_bases.py:2255, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2251 try:
#    2252     # _get_renderer may change the figure dpi (as vector formats
#    2253     # force the figure dpi to 72), so we need to set it again here.
#    2254     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255         result = print_method(
#    2256             filename,
#    2257             facecolor=facecolor,
#    2258             edgecolor=edgecolor,
#    2259             orientation=orientation,
#    2260             bbox_inches_restore=_bbox_inches_restore,
#    2261             **kwargs)
#    2262 finally:
#    2263     if bbox_inches and restore_bbox:
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\backend_bases.py:1669, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1661     _api.warn_deprecated(
#    1662         '3.3', name=name,
#    1663         message='%(name)s() got unexpected keyword argument "'
#    1664                 + arg + '" which is no longer supported as of '
#    1665                 '%(since)s and will become an error '
#    1666                 '%(removal)s')
#    1667     kwargs.pop(arg)
# -> 1669 return func(*args, **kwargs)
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\backends\backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     462 """
#     463 Write the figure to a PNG file.
#     464
#    (...)
#     506     *metadata*, including the default 'Software' key.
#     507 """
#     508 FigureCanvasAgg.draw(self)
# --> 509 mpl.image.imsave(
#     510     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File d:\python\Miniconda3\lib\site-packages\matplotlib\image.py:1616, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614 pil_kwargs.setdefault("format", format)
#    1615 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616 image.save(fname, **pil_kwargs)
#
# File d:\python\Miniconda3\lib\site-packages\PIL\Image.py:2232, in Image.save(self, fp, format, **params)
#    2230         fp = builtins.open(filename, "r+b")
#    2231     else:
# -> 2232         fp = builtins.open(filename, "w+b")
#    2234 try:
#    2235     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/桌面/1.png'

# %%
from sklearn.datasets import load_iris
from sklearn import tree

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
 
# 加载数据集
iris = load_iris()
X = iris.data
y = iris.target
 
# 将数据集分成训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
 
# 创建一个决策树分类器
dc_tree = tree.DecisionTreeClassifier(criterion='entropy',min_samples_leaf=5)
 
# 使用训练集训练分类器
dc_tree.fit(X_train, y_train)
 
# 使用测试集进行预测
y_pred = dc_tree.predict(X_test)
 
# 计算分类器的准确率
accuracy = accuracy_score(y_test, y_pred)
 
print("决策树分类器的准确率为：", accuracy)

import matplotlib as mpl
font2 = {'family' : 'SimHei',
'weight' : 'normal',
'size'   : 20,
}
mpl.rcParams['font.family'] = 'SimHei'
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(20,20))
tree.plot_tree(dc_tree,filled='True',
               feature_names=['花萼长', '花萼宽', '花瓣长', '花瓣宽'],
               class_names=['山鸢尾', '变色鸢尾', '维吉尼亚鸢尾'])
# Out:
# 决策树分类器的准确率为： 0.9555555555555556
# [Text(0.375, 0.875, '花瓣长 <= 2.6\nentropy = 1.582\nsamples = 105\nvalue = [36, 32, 37]\nclass = 维吉尼亚鸢尾'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 36\nvalue = [36, 0, 0]\nclass = 山鸢尾'),
#  Text(0.5, 0.625, '花瓣宽 <= 1.65\nentropy = 0.996\nsamples = 69\nvalue = [0, 32, 37]\nclass = 维吉尼亚鸢尾'),
#  Text(0.25, 0.375, '花瓣长 <= 4.85\nentropy = 0.431\nsamples = 34\nvalue = [0, 31, 3]\nclass = 变色鸢尾'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 28\nvalue = [0, 28, 0]\nclass = 变色鸢尾'),
#  Text(0.375, 0.125, 'entropy = 1.0\nsamples = 6\nvalue = [0, 3, 3]\nclass = 变色鸢尾'),
#  Text(0.75, 0.375, '花萼长 <= 5.95\nentropy = 0.187\nsamples = 35\nvalue = [0, 1, 34]\nclass = 维吉尼亚鸢尾'),
#  Text(0.625, 0.125, 'entropy = 0.592\nsamples = 7\nvalue = [0, 1, 6]\nclass = 维吉尼亚鸢尾'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 28\nvalue = [0, 0, 28]\nclass = 维吉尼亚鸢尾')]
